# %% [markdown]
# <a href="https://colab.research.google.com/github/A01749128/A01749128/blob/main/Clase01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Titulo

# %%
file_path="/content/drive/MyDrive/datasets/AccidentsFull.csv"

# %%
import pandas as pd

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#    HOUR_I_R  ALCHL_I  ALIGN_I  STRATUM_R  WRK_ZONE  WKDY_I_R  INT_HWY  \
# 0         0        2        2          1         0         1        0
# 1         1        2        1          0         0         1        1
# 2         1        2        1          0         0         1        0
# 3         1        2        1          1         0         0        0
# 4         1        1        1          0         0         1        0
#
#    LGTCON_I_R  MANCOL_I_R  PED_ACC_R  ...  SUR_COND  TRAF_CON_R  TRAF_WAY  \
# 0           3           0          0  ...         4           0         3
# 1           3           2          0  ...         4           0         3
# 2           3           2          0  ...         4           1         2
# 3           3           2          0  ...         4           1         2
# 4           3           2          0  ...         4           0         2
#
#    VEH_INVL  WEATHER_R  INJURY_CRASH  NO_INJ_I  PRPTYDMG_CRASH  FATALITIES  \
# ...
